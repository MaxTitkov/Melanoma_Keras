# 10. ÐÑÑÑ Ð»Ð¸ ÑÑÐ±ÐµÑÐºÑÐ»ÐµÐ·;
# 12. ÐÐ½ÑÐµÑÐ²Ð°Ð» Ð¼ÐµÐ¶Ð´Ñ Ð·Ð°Ð¿Ð¸ÑÑÑ Ð¸ Ð²ÑÐµÐ¼ÐµÐ½ÐµÐ¼ Ð¿ÑÐ¸ÑÐ¼Ð° (Ð´Ð½ÐµÐ¹);

# %%
dataset
# Out:
#         Age Gender AppointmentRegistration        ApointmentData DayOfTheWeek  \
# 0        19      M    2014-12-16T14:46:25Z  2015-01-14T00:00:00Z    Wednesday
# 1        24      F    2015-08-18T07:01:26Z  2015-08-19T00:00:00Z    Wednesday
# 2         4      F    2014-02-17T12:53:46Z  2014-02-18T00:00:00Z      Tuesday
# 3         5      M    2014-07-23T17:02:11Z  2014-08-07T00:00:00Z     Thursday
# 4        38      M    2015-10-21T15:20:09Z  2015-10-27T00:00:00Z      Tuesday
# 5         5      F    2014-06-17T06:47:27Z  2014-07-22T00:00:00Z      Tuesday
# 6        46      F    2015-06-19T19:53:58Z  2015-07-07T00:00:00Z      Tuesday
# 7         4      F    2015-08-07T08:19:19Z  2015-08-21T00:00:00Z       Friday
# 8        20      F    2014-10-14T11:46:36Z  2014-10-28T00:00:00Z      Tuesday
# 9        51      F    2014-06-13T07:50:43Z  2014-06-17T00:00:00Z      Tuesday
# 10       33      M    2015-10-01T08:43:18Z  2015-11-09T00:00:00Z       Monday
# ...

# %% [markdown]
# ### ÐÑÐµÐ´Ð¾Ð±ÑÐ°Ð±Ð¾ÑÐºÐ° Ð´Ð°Ð½Ð½ÑÑ:

# %%
age_drop=dataset[dataset.Age<0]
dataset_1=dataset.drop(age_drop.index, axis=0)

# %%
X=dataset_1.iloc[:, [0, 1,4, 6,7,8,9,10,11,12,13,14]].values
y=dataset_1.iloc[:, 5].values

# %%
X[0]
# Out:
# array([19, 'M', 0, 0, 0, 0, 0, 0, 0, 0, -29], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
binarizer_1=LabelEncoder()
X[:, 1]=binarizer_1.fit_transform(X[:, 1])
y=binarizer_1.fit_transform(y)

binarizer_2=LabelEncoder()
X[:, 2]=binarizer_4.fit_transform(X[:, 2])
one_hot_day_of_week=OneHotEncoder(categorical_features=[2])
X=one_hot_day_of_week.fit_transform(X).toarray()
X=X[:, 1:]

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
# Out:
# /home/nbuser/anaconda3_431/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %% [markdown]
# ### Ð¡Ð¾Ð´Ð°Ð½Ð¸Ðµ Ð¼Ð¾Ð´ÐµÐ»Ð¸ Ð¸ÑÐºÑÑÑÑÐ²ÐµÐ½Ð½Ð¾Ð¹ Ð½ÐµÐ¹ÑÐ¾Ð½Ð½Ð¾Ð¹ ÑÐµÑÐ¸

# %%
from keras.models import Sequential
from keras.layers import Dense, PReLU, LeakyReLU
from keras.optimizers import SGD, RMSprop, Adagrad

rms1=RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0)

classifier=Sequential()
classifier.add(Dense(units=32, kernel_initializer='uniform', input_dim=X_train.shape[1]))
classifier.add(PReLU())
classifier.add(Dense(units=16, kernel_initializer='uniform', input_dim=X_train.shape[1]))
classifier.add(PReLU())
classifier.add(Dense(units=8, kernel_initializer='uniform', input_dim=X_train.shape[1]))
classifier.add(PReLU())
classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))


classifier.compile(optimizer=rms1, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### ÐÐ±ÑÑÐµÐ½Ð¸Ðµ Ð¼Ð¾Ð´ÐµÐ»Ð¸:

# %%
classifier.fit(X_train, y_train, epochs=10000, batch_size=1000, verbose=2, class_weight = 'auto')
# Out:
# Epoch 1/10000
# 0s - loss: 0.5989 - acc: 0.6984
# Epoch 2/10000
# 1s - loss: 0.5989 - acc: 0.6985
# Epoch 3/10000
# 1s - loss: 0.5989 - acc: 0.6984
# Epoch 4/10000
# 0s - loss: 0.5989 - acc: 0.6984
# Epoch 5/10000
# 1s - loss: 0.5988 - acc: 0.6984
# Epoch 6/10000
# 1s - loss: 0.5988 - acc: 0.6985
# Epoch 7/10000
# 1s - loss: 0.5988 - acc: 0.6985
# Epoch 8/10000
# 1s - loss: 0.5988 - acc: 0.6985
# Epoch 9/10000
# 1s - loss: 0.5988 - acc: 0.6985
# Epoch 10/10000
# 1s - loss: 0.5988 - acc: 0.6986
# Epoch 11/10000
# 0s - loss: 0.5987 - acc: 0.6986
# Epoch 12/10000
# 0s - loss: 0.5988 - acc: 0.6985
# Epoch 13/10000
# 1s - loss: 0.5987 - acc: 0.6985
# Epoch 14/10000
# 1s - loss: 0.5987 - acc: 0.6986
# Epoch 15/10000
# 1s - loss: 0.5987 - acc: 0.6985
# Epoch 16/10000
# 0s - loss: 0.5987 - acc: 0.6986
# Epoch 17/10000
# 0s - loss: 0.5987 - acc: 0.6985
# Epoch 18/10000
# 1s - loss: 0.5987 - acc: 0.6985
# Epoch 19/10000
# 1s - loss: 0.5987 - acc: 0.6986
# Epoch 20/10000
# ...

# %% [markdown]
# ### ÐÐ°Ð»Ð¸Ð´Ð°ÑÐ¸Ñ Ð¼Ð¾Ð´ÐµÐ»Ð¸ Ð½Ð° ÑÐµÑÑÐ¾Ð²Ð¾Ð¹ Ð²ÑÐ±Ð¾ÑÐºÐµ (Ð½Ð° Ð´Ð°Ð½Ð½ÑÑ, ÐºÐ¾ÑÐ¾ÑÑÐµ Ð¼Ð¾Ð´ÐµÐ»Ñ "Ð½Ðµ Ð²Ð¸Ð´ÐµÐ»Ð°")

# %%
y_pred=classifier.predict_classes(X_test, verbose=2)

# %% [markdown]
# ### ÑÐ¾ÑÐ½Ð¾ÑÑÑ Ð¼Ð¾Ð´ÐµÐ»Ð¸ = ÐºÐ¾Ð»Ð¸ÑÐµÑÑÐ²Ð¾ Ð¿ÑÐ°Ð²Ð¸Ð»ÑÐ½ÑÑ Ð¿ÑÐ¾Ð³Ð½Ð¾Ð·Ð¾Ð² / Ð¾Ð±ÑÐµÐµ ÐºÐ¾Ð»Ð¸ÑÐµÑÑÐ²Ð¾ Ð¿ÑÐ¾Ð³Ð½Ð¾Ð·Ð¾Ð²

# %%
accuracy=classifier.evaluate(X_test, y_test, batch_size=1, verbose=2)
print(' Ð¢Ð¾ÑÐ½Ð¾ÑÑÑ Ð¼Ð¾Ð´ÐµÐ»Ð¸: %.1f'% (accuracy[1]*100), "%")
# Out:
#  Ð¢Ð¾ÑÐ½Ð¾ÑÑÑ Ð¼Ð¾Ð´ÐµÐ»Ð¸: 69.6 %

# %% [markdown]
# ### Ð¢Ð¾ÑÐ½Ð¾ÑÑÑ Ð¼Ð¾Ð´ÐµÐ»Ð¸ ÑÐ¾ÑÑÐ°Ð²Ð¸Ð»Ð°: 69.6 %

# %% [markdown]
# ### ÐÐ»Ñ Ð´Ð°Ð½Ð½Ð¾Ð³Ð¾ Ð½Ð°Ð±Ð¾ÑÐ° Ð´Ð°Ð½Ð½ÑÑ ÑÐ°Ð¼Ð°Ñ Ð²ÑÑÐ¾ÐºÐ°Ñ ÑÐ¾ÑÐ½Ð¾ÑÑÑ Ð¼Ð¾Ð´ÐµÐ»Ð¸ 